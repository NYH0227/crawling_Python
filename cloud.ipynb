# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re


page = 1
page = min(page,35)

object = []
cloud = dict()

for i in range(1,page+1):
    global object,cloud
    url = "https://finance.naver.com/sise/sise_market_sum.nhn?sosok=0&page="+str(i)

    html = urlopen(url)
    soup = BeautifulSoup(html, 'html.parser')

    list = soup.find_all("tr")

    for i in list[7:86]:
        if len(i)==1 :continue
        ob = dict()
        t = i.text.split()
        #ob[t[1]] = t
        cloud[t[1]] = int(int(re.sub("[.,%]","",t[9]))/10000)
        

        ob["순위"] = int(t[0])
        ob["종목이름"] = t[1]
        ob["가격"] = int(re.sub(",","",t[2]))
        ob["전일비"] = int(re.sub("[,%]","",t[3]))
        ob["등락률"] = float(re.sub("[+,%]","",t[4]))
        ob["시가총액"] = int(re.sub(",","",t[6]))
        ob["거래량"] = int(re.sub(",","",t[9]))
        
        object.append(ob)

for i in object:
    print(i)

#print(cloud)
# Out:
# {'순위': 1, '종목이름': '삼성전자', '가격': 65700, '전일비': 0, '등락률': 0.0, '시가총액': 3922147, '거래량': 12262239}
# {'순위': 2, '종목이름': 'LG에너지솔루션', '가격': 391500, '전일비': 2000, '등락률': -0.51, '시가총액': 916110, '거래량': 235961}
# {'순위': 3, '종목이름': 'SK하이닉스', '가격': 110500, '전일비': 500, '등락률': 0.45, '시가총액': 804443, '거래량': 3634395}
# {'순위': 4, '종목이름': '삼성바이오로직스', '가격': 793000, '전일비': 5000, '등락률': -0.63, '시가총액': 564410, '거래량': 29599}
# {'순위': 5, '종목이름': '삼성전자우', '가격': 58200, '전일비': 200, '등락률': -0.34, '시가총액': 478920, '거래량': 1001077}
# {'순위': 6, '종목이름': 'NAVER', '가격': 279000, '전일비': 3000, '등락률': 1.09, '시가총액': 457697, '거래량': 471947}
# {'순위': 7, '종목이름': '삼성SDI', '가격': 584000, '전일비': 9000, '등락률': -1.52, '시가총액': 401585, '거래량': 275294}
# {'순위': 8, '종목이름': '현대차', '가격': 183000, '전일비': 2500, '등락률': 1.39, '시가총액': 391013, '거래량': 722462}
# {'순위': 9, '종목이름': '카카오', '가격': 85400, '전일비': 1800, '등락률': 2.15, '시가총액': 381115, '거래량': 1362386}
# {'순위': 10, '종목이름': 'LG화학', '가격': 520000, '전일비': 19000, '등락률': 3.79, '시가총액': 367080, '거래량': 238255}
# {'순위': 11, '종목이름': '기아', '가격': 86100, '전일비': 2000, '등락률': 2.38, '시가총액': 349018, '거래량': 2537954}
# {'순위': 12, '종목이름': 'POSCO홀딩스', '가격': 274500, '전일비': 1500, '등락률': -0.54, '시가총액': 239328, '거래량': 176372}
# {'순위': 13, '종목이름': 'KB금융', '가격': 56900, '전일비': 1100, '등락률': -1.9, '시가총액': 234629, '거래량': 1235789}
# {'순위': 14, '종목이름': '셀트리온', '가격': 162000, '전일비': 0, '등락률': 0.0, '시가총액': 227915, '거래량': 235236}
# {'순위': 15, '종목이름': '삼성물산', '가격': 111500, '전일비': 500, '등락률': -0.45, '시가총액': 208379, '거래량': 197765}
# {'순위': 16, '종목이름': '신한지주', '가격': 40450, '전일비': 650, '등락률': -1.58, '시가총액': 207482, '거래량': 1148482}
# {'순위': 17, '종목이름': '카카오뱅크', '가격': 40100, '전일비': 50, '등락률': 0.12, '시가총액': 190955, '거래량': 953069}
# {'순위': 18, '종목이름': '현대모비스', '가격': 198500, '전일비': 500, '등락률': -0.25, '시가총액': 187728, '거래량': 255180}
# {'순위': 19, '종목이름': 'SK이노베이션', '가격': 200000, '전일비': 1000, '등락률': -0.5, '시가총액': 184931, '거래량': 184448}
# {'순위': 20, '종목이름': 'SK', '가격': 244000, '전일비': 2500, '등락률': -1.01, '시가총액': 180924, '거래량': 167787}
# {'순위': 21, '종목이름': 'LG전자', '가격': 109000, '전일비': 2500, '등락률': -2.24, '시가총액': 178376, '거래량': 1258422}
# {'순위': 22, '종목이름': 'HMM', '가격': 29700, '전일비': 1050, '등락률': 3.66, '시가총액': 145245, '거래량': 4923343}
# {'순위': 23, '종목이름': '한국전력', '가격': 22100, '전일비': 500, '등락률': -2.21, '시가총액': 141874, '거래량': 1494148}
# {'순위': 24, '종목이름': '하나금융지주', '가격': 44500, '전일비': 1450, '등락률': -3.16, '시가총액': 133608, '거래량': 1297044}
# {'순위': 25, '종목이름': 'SK텔레콤', '가격': 59600, '전일비': 500, '등락률': 0.85, '시가총액': 130425, '거래량': 567819}
# {'순위': 26, '종목이름': '두산에너빌리티', '가격': 20100, '전일비': 350, '등락률': -1.71, '시가총액': 127046, '거래량': 3390273}
# {'순위': 27, '종목이름': '삼성생명', '가격': 63400, '전일비': 100, '등락률': -0.16, '시가총액': 126800, '거래량': 163015}
# {'순위': 28, '종목이름': 'LG생활건강', '가격': 811000, '전일비': 4000, '등락률': 0.5, '시가총액': 126664, '거래량': 57918}
# {'순위': 29, '종목이름': '크래프톤', '가격': 257000, '전일비': 12000, '등락률': 4.9, '시가총액': 126115, '거래량': 214337}
# {'순위': 30, '종목이름': '카카오페이', '가격': 91400, '전일비': 500, '등락률': -0.54, '시가총액': 121088, '거래량': 331354}
# {'순위': 31, '종목이름': '삼성전기', '가격': 160000, '전일비': 500, '등락률': -0.31, '시가총액': 119510, '거래량': 296506}
# {'순위': 32, '종목이름': 'S-Oil', '가격': 106000, '전일비': 1000, '등락률': -0.93, '시가총액': 119338, '거래량': 463265}
# {'순위': 33, '종목이름': 'KT&G', '가격': 81800, '전일비': 800, '등락률': -0.97, '시가총액': 112305, '거래량': 286127}
# {'순위': 34, '종목이름': 'LG', '가격': 70700, '전일비': 200, '등락률': -0.28, '시가총액': 111212, '거래량': 168193}
# {'순위': 35, '종목이름': '현대중공업', '가격': 125000, '전일비': 5500, '등락률': -4.21, '시가총액': 110966, '거래량': 458902}
# {'순위': 36, '종목이름': '삼성에스디에스', '가격': 143000, '전일비': 1500, '등락률': -1.04, '시가총액': 110650, '거래량': 112451}
# {'순위': 37, '종목이름': '우리금융지주', '가격': 14650, '전일비': 300, '등락률': -2.01, '시가총액': 106661, '거래량': 2502322}
# {'순위': 38, '종목이름': '대한항공', '가격': 29400, '전일비': 50, '등락률': 0.17, '시가총액': 102259, '거래량': 752947}
# {'순위': 39, '종목이름': '고려아연', '가격': 538000, '전일비': 13000, '등락률': -2.36, '시가총액': 101521, '거래량': 39063}
# {'순위': 40, '종목이름': '아모레퍼시픽', '가격': 168500, '전일비': 1000, '등락률': 0.6, '시가총액': 98560, '거래량': 380298}
# {'순위': 41, '종목이름': '포스코케미칼', '가격': 124000, '전일비': 2500, '등락률': -1.98, '시가총액': 96054, '거래량': 242497}
# {'순위': 42, '종목이름': 'SK바이오사이언스', '가격': 124000, '전일비': 4500, '등락률': 3.77, '시가총액': 95212, '거래량': 396326}
# {'순위': 43, '종목이름': '하이브', '가격': 228000, '전일비': 2500, '등락률': -1.08, '시가총액': 94286, '거래량': 170588}
# {'순위': 44, '종목이름': '삼성화재', '가격': 196000, '전일비': 3500, '등락률': -1.75, '시가총액': 92855, '거래량': 86428}
# {'순위': 45, '종목이름': 'KT', '가격': 35450, '전일비': 700, '등락률': -1.94, '시가총액': 92564, '거래량': 990452}
# {'순위': 46, '종목이름': '엔씨소프트', '가격': 413000, '전일비': 5000, '등락률': 1.23, '시가총액': 90670, '거래량': 67766}
# {'순위': 47, '종목이름': 'SK아이이테크놀로지', '가격': 115000, '전일비': 1000, '등락률': 0.88, '시가총액': 81992, '거래량': 153738}
# {'순위': 48, '종목이름': '기업은행', '가격': 10900, '전일비': 200, '등락률': -1.8, '시가총액': 81129, '거래량': 1277285}
# {'순위': 49, '종목이름': 'LG이노텍', '가격': 341000, '전일비': 2500, '등락률': 0.74, '시가총액': 80705, '거래량': 189119}
# {'순위': 50, '종목이름': '현대글로비스', '가격': 207500, '전일비': 4500, '등락률': 2.22, '시가총액': 77812, '거래량': 146392}

# %%
from collections import Counter
import pytagcloud
from wordcloud import WordCloud

# %%
c = Counter(cloud)
path = '/System/Library/Fonts/Supplemental/AppleGothic.ttf'
tag = c.most_common(50)


wc = WordCloud(font_path=path , background_color="white", width=1000,height=700, max_words=60, max_font_size=200)
wc.generate_from_frequencies(dict(tag))
wc.to_file('wctest.png')
